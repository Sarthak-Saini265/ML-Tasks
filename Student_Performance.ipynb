# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression

# %%
file = pd.read_csv('Student_Performance.csv')
data = file.copy()
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#         Hours Studied  Previous Scores Extracurricular Activities  \
# count    10000.000000     10000.000000                      10000
# unique            NaN              NaN                          2
# top               NaN              NaN                         No
# freq              NaN              NaN                       5052
# mean         4.992900        69.445700                        NaN
# std          2.589309        17.343152                        NaN
# min          1.000000        40.000000                        NaN
# 25%          3.000000        54.000000                        NaN
# 50%          5.000000        69.000000                        NaN
# 75%          7.000000        85.000000                        NaN
# max          9.000000        99.000000                        NaN
#
#          Sleep Hours  Sample Question Papers Practiced  Performance Index
# count   10000.000000                      10000.000000       10000.000000
# ...

# %%
sns.distplot(data['Performance Index'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\3214267388.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Performance Index'])
# <Axes: xlabel='Performance Index', ylabel='Density'>

# %%
sns.distplot(data['Previous Scores'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\3755831258.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Previous Scores'])
# <Axes: xlabel='Previous Scores', ylabel='Density'>

# %%
sns.distplot(data['Hours Studied'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\2283209712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Hours Studied'])
# <Axes: xlabel='Hours Studied', ylabel='Density'>

# %%
sns.distplot(data['Performance Index'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\3214267388.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Performance Index'])
# <Axes: xlabel='Performance Index', ylabel='Density'>

# %%
sns.distplot(data['Sample Question Papers Practiced'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\806967473.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sample Question Papers Practiced'])
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Density'>

# %%
sns.distplot(data['Sleep Hours'])
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_29540\1212292332.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sleep Hours'])
# <Axes: xlabel='Sleep Hours', ylabel='Density'>

# %%
data.describe(include='all')
# Out:
#         Hours Studied  Previous Scores Extracurricular Activities  \
# count    10000.000000     10000.000000                      10000
# unique            NaN              NaN                          2
# top               NaN              NaN                         No
# freq              NaN              NaN                       5052
# mean         4.992900        69.445700                        NaN
# std          2.589309        17.343152                        NaN
# min          1.000000        40.000000                        NaN
# 25%          3.000000        54.000000                        NaN
# 50%          5.000000        69.000000                        NaN
# 75%          7.000000        85.000000                        NaN
# max          9.000000        99.000000                        NaN
#
#          Sleep Hours  Sample Question Papers Practiced  Performance Index
# count   10000.000000                      10000.000000       10000.000000
# ...

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3))
ax1.scatter(data['Previous Scores'],data['Performance Index'])
ax1.set_title('Perf_Index and Prev_scores')
ax2.scatter(data['Hours Studied'],data['Performance Index'])
ax2.set_title('Perf_Index and Hours_studied')
ax3.scatter(data['Sleep Hours'],data['Performance Index'])
ax3.set_title('Perf_Index and Sleep_hours')


plt.show()

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data.drop('Previous Scores', axis=1)[['Hours Studied', 'Sleep Hours', 'Sample Question Papers Practiced' ]]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#         VIF                          features
# 0  3.946261                     Hours Studied
# 1  5.173927                       Sleep Hours
# 2  3.166949  Sample Question Papers Practiced

# %% [markdown]
# ## Creating Dummies

# %%
data_with_dummies = pd.get_dummies(data, drop_first=True)

# %%
data_with_dummies['Extracurricular Activities_Yes'] = data_with_dummies['Extracurricular Activities_Yes'].astype(int)

# %%
data_with_dummies
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index  \
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...

# %% [markdown]
# ## Standardization

# %%
targets = data_with_dummies['Performance Index']
inputs = data_with_dummies.drop(['Performance Index'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state = 44)

# %% [markdown]
# ## Regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
y_hat
# Out:
# array([87.20840569, 81.32708226, 42.18734282, ..., 54.94393231,
#        88.80399354, 21.60775881])

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Targets (y_train)',size=18)
plt.ylabel('Predictions (y_hat)',size=18)
plt.show()

# %%
reg.score(x_test, y_test)
# Out:
# 0.988669795142709

# %%
sns.distplot(y_train - y_hat)
plt.title("Residuals PDF", size=18)
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_22116\329104437.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train - y_hat)
# Text(0.5, 1.0, 'Residuals PDF')

# %% [markdown]
# ## Testing

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test, alpha=0.2)
plt.xlabel('Targets (y_test)',size=18)
plt.ylabel('Predictions (y_hat_test)',size=18)
plt.show()

# %%
df_predict = pd.DataFrame(y_hat_test, columns = ['Predictions'])
df_predict.head()
# Out:
#    Predictions
# 0    43.847224
# 1    41.263898
# 2    33.830455
# 3    17.475919
# 4    72.418184

# %%
y_test = y_test.reset_index(drop=True)
y_test.head()
# Out:
# 0    47.0
# 1    43.0
# 2    34.0
# 3    18.0
# 4    73.0
# Name: Performance Index, dtype: float64

# %%
df_predict['Target'] = y_test
df_predict
# Out:
#       Predictions  Target
# 0       43.847224    47.0
# 1       41.263898    43.0
# 2       33.830455    34.0
# 3       17.475919    18.0
# 4       72.418184    73.0
# ...           ...     ...
# 1995    84.377408    84.0
# 1996    94.426455    91.0
# 1997    54.475928    55.0
# 1998    62.495300    62.0
# 1999    32.921130    31.0
#
# [2000 rows x 2 columns]

# %%
df_predict['Residual'] = df_predict['Target'] - df_predict['Predictions']

# %%
df_predict
# Out:
#       Predictions  Target  Residual
# 0       43.847224    47.0  3.152776
# 1       41.263898    43.0  1.736102
# 2       33.830455    34.0  0.169545
# 3       17.475919    18.0  0.524081
# 4       72.418184    73.0  0.581816
# ...           ...     ...       ...
# 1995    84.377408    84.0 -0.377408
# 1996    94.426455    91.0 -3.426455
# 1997    54.475928    55.0  0.524072
# 1998    62.495300    62.0 -0.495300
# 1999    32.921130    31.0 -1.921130
#
# [2000 rows x 3 columns]

# %%
df_predict['Difference%'] = np.absolute(df_predict['Residual']/df_predict['Target']*100)

# %%
df_predict
# Out:
#       Predictions  Target  Residual  Difference%
# 0       43.847224    47.0  3.152776     6.708035
# 1       41.263898    43.0  1.736102     4.037446
# 2       33.830455    34.0  0.169545     0.498660
# 3       17.475919    18.0  0.524081     2.911560
# 4       72.418184    73.0  0.581816     0.797008
# ...           ...     ...       ...          ...
# 1995    84.377408    84.0 -0.377408     0.449295
# 1996    94.426455    91.0 -3.426455     3.765335
# 1997    54.475928    55.0  0.524072     0.952858
# 1998    62.495300    62.0 -0.495300     0.798871
# 1999    32.921130    31.0 -1.921130     6.197192
#
# [2000 rows x 4 columns]

# %%
df_predict.describe()
# Out:
#        Predictions       Target     Residual  Difference%
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean     55.057953    55.054000    -0.003953     3.527748
# std      19.307030    19.392966     2.064250     3.502432
# min      13.038100    11.000000    -6.856631     0.005441
# 25%      39.906317    40.000000    -1.340738     1.135913
# 50%      54.567015    55.000000    -0.040018     2.539001
# 75%      70.509373    70.250000     1.407749     4.742990
# max      97.552241    99.000000     8.782394    27.788549

# %%
pd.options.display.max_rows = 999
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_predict.sort_values(by=['Difference%'])
# Out:
#       Predictions  Target  Residual  Difference%
# 524         56.00   56.00     -0.00         0.01
# 1936        59.00   59.00     -0.00         0.01
# 315         61.99   62.00      0.01         0.02
# 19          45.99   46.00      0.01         0.02
# 1377        87.02   87.00     -0.02         0.02
# ...           ...     ...       ...          ...
# 1735        14.92   12.00     -2.92        24.37
# 1511        15.07   20.00      4.93        24.66
# 1472        19.97   16.00     -3.97        24.78
# 1946        21.50   17.00     -4.50        26.46
# 275         14.06   11.00     -3.06        27.79
#
# [2000 rows x 4 columns]
