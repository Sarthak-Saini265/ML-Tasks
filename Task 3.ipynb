# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
file = pd.read_csv('Iris-Dataset.csv')
data = file.copy()
data
# Out:
#       x1   x2   x3   x4               y
# 0    5.1  3.5  1.4  0.2     Iris-Setosa
# 1    4.9  3.0  1.4  0.2     Iris-Setosa
# 2    4.7  3.2  1.3  0.2     Iris-Setosa
# 3    4.6  3.1  1.5  0.2     Iris-Setosa
# 4    5.0  3.6  1.4  0.2     Iris-Setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-Virginica
# 146  6.3  2.5  5.0  1.9  Iris-Virginica
# 147  6.5  3.0  5.2  2.0  Iris-Virginica
# 148  6.2  3.4  5.4  2.3  Iris-Virginica
# 149  5.9  3.0  5.1  1.8  Iris-Virginica
#
# [150 rows x 5 columns]

# %%
indices_to_select = np.random.choice(data[data['y'] == 'Iris-Setosa'].index, size=40, replace=False)
cluster_setosa = data.loc[indices_to_select]
data = data.drop(indices_to_select)

# %%
cluster_setosa
# Out:
#      x1   x2   x3   x4            y
# 11  4.8  3.4  1.6  0.2  Iris-Setosa
# 47  4.6  3.2  1.4  0.2  Iris-Setosa
# 22  4.6  3.6  1.0  0.2  Iris-Setosa
# 44  5.1  3.8  1.9  0.4  Iris-Setosa
# 40  5.0  3.5  1.3  0.3  Iris-Setosa
# 32  5.2  4.1  1.5  0.1  Iris-Setosa
# 27  5.2  3.5  1.5  0.2  Iris-Setosa
# 41  4.5  2.3  1.3  0.3  Iris-Setosa
# 24  4.8  3.4  1.9  0.2  Iris-Setosa
# 43  5.0  3.5  1.6  0.6  Iris-Setosa
# 15  5.7  4.4  1.5  0.4  Iris-Setosa
# 45  4.8  3.0  1.4  0.3  Iris-Setosa
# 26  5.0  3.4  1.6  0.4  Iris-Setosa
# 38  4.4  3.0  1.3  0.2  Iris-Setosa
# 29  4.7  3.2  1.6  0.2  Iris-Setosa
# 39  5.1  3.4  1.5  0.2  Iris-Setosa
# 20  5.4  3.4  1.7  0.2  Iris-Setosa
# 5   5.4  3.9  1.7  0.4  Iris-Setosa
# 6   4.6  3.4  1.4  0.3  Iris-Setosa
# 2   4.7  3.2  1.3  0.2  Iris-Setosa
# 18  5.7  3.8  1.7  0.3  Iris-Setosa
# 8   4.4  2.9  1.4  0.2  Iris-Setosa
# 4   5.0  3.6  1.4  0.2  Iris-Setosa
# 48  5.3  3.7  1.5  0.2  Iris-Setosa
# 16  5.4  3.9  1.3  0.4  Iris-Setosa
# ...

# %%
indices_to_select = np.random.choice(data[data['y'] == 'Iris-Versicolour'].index, size=40, replace=False)
cluster_versicolour = data.loc[indices_to_select]
data = data.drop(indices_to_select)

# %%
cluster_versicolour
# Out:
#      x1   x2   x3   x4                 y
# 69  5.6  2.5  3.9  1.1  Iris-Versicolour
# 89  5.5  2.5  4.0  1.3  Iris-Versicolour
# 54  6.5  2.8  4.6  1.5  Iris-Versicolour
# 94  5.6  2.7  4.2  1.3  Iris-Versicolour
# 81  5.5  2.4  3.7  1.0  Iris-Versicolour
# 80  5.5  2.4  3.8  1.1  Iris-Versicolour
# 57  4.9  2.4  3.3  1.0  Iris-Versicolour
# 95  5.7  3.0  4.2  1.2  Iris-Versicolour
# 51  6.4  3.2  4.5  1.5  Iris-Versicolour
# 85  6.0  3.4  4.5  1.6  Iris-Versicolour
# 59  5.2  2.7  3.9  1.4  Iris-Versicolour
# 90  5.5  2.6  4.4  1.2  Iris-Versicolour
# 96  5.7  2.9  4.2  1.3  Iris-Versicolour
# 61  5.9  3.0  4.2  1.5  Iris-Versicolour
# 67  5.8  2.7  4.1  1.0  Iris-Versicolour
# 84  5.4  3.0  4.5  1.5  Iris-Versicolour
# 88  5.6  3.0  4.1  1.3  Iris-Versicolour
# 98  5.1  2.5  3.0  1.1  Iris-Versicolour
# 91  6.1  3.0  4.6  1.4  Iris-Versicolour
# 71  6.1  2.8  4.0  1.3  Iris-Versicolour
# 86  6.7  3.1  4.7  1.5  Iris-Versicolour
# 58  6.6  2.9  4.6  1.3  Iris-Versicolour
# ...

# %%
indices_to_select = np.random.choice(data[data['y'] == 'Iris-Virginica'].index, size=40, replace=False)
cluster_virginica = data.loc[indices_to_select]
data = data.drop(indices_to_select)

# %%
cluster_virginica
# Out:
#       x1   x2   x3   x4               y
# 137  6.4  3.1  5.5  1.8  Iris-Virginica
# 146  6.3  2.5  5.0  1.9  Iris-Virginica
# 124  6.7  3.3  5.7  2.1  Iris-Virginica
# 115  6.4  3.2  5.3  2.3  Iris-Virginica
# 140  6.7  3.1  5.6  2.4  Iris-Virginica
# 116  6.5  3.0  5.5  1.8  Iris-Virginica
# 110  6.5  3.2  5.1  2.0  Iris-Virginica
# 134  6.1  2.6  5.6  1.4  Iris-Virginica
# 133  6.3  2.8  5.1  1.5  Iris-Virginica
# 128  6.4  2.8  5.6  2.1  Iris-Virginica
# 112  6.8  3.0  5.5  2.1  Iris-Virginica
# 118  7.7  2.6  6.9  2.3  Iris-Virginica
# 131  7.9  3.8  6.4  2.0  Iris-Virginica
# 141  6.9  3.1  5.1  2.3  Iris-Virginica
# 100  6.3  3.3  6.0  2.5  Iris-Virginica
# 143  6.8  3.2  5.9  2.3  Iris-Virginica
# 126  6.2  2.8  4.8  1.8  Iris-Virginica
# 111  6.4  2.7  5.3  1.9  Iris-Virginica
# 106  4.9  2.5  4.5  1.7  Iris-Virginica
# 136  6.3  3.4  5.6  2.4  Iris-Virginica
# 135  7.7  3.0  6.1  2.3  Iris-Virginica
# 144  6.7  3.3  5.7  2.5  Iris-Virginica
# ...

# %%
plt.scatter(cluster_setosa['x1'], cluster_setosa['x2'])
plt.scatter(cluster_versicolour['x1'], cluster_versicolour['x2'], color='orange')
plt.scatter(cluster_virginica['x1'], cluster_virginica['x2'],color='limegreen')
plt.show()

# %%
mean_setosa = [sum(cluster_setosa.iloc[:, i])/len(cluster_setosa) for i in range(4)]
mean_versicolour = [sum(cluster_versicolour.iloc[:, i])/len(cluster_versicolour) for i in range(4)]
mean_virginica = [sum(cluster_virginica.iloc[:, i])/len(cluster_virginica) for i in range(4)]
mean_setosa
# Out:
# [4.9925000000000015, 3.4175000000000004, 1.4674999999999998, 0.255]

# %%
mean_versicolour
# Out:
# [5.924999999999999, 2.7600000000000002, 4.2275, 1.3024999999999998]

# %%
mean_virginica
# Out:
# [6.58, 2.9974999999999996, 5.5575, 2.03]

# %%
def distance(row):
    distance = {}
    distance['Setosa'] = (math.sqrt((row[0] - mean_setosa[0])**2 + (row[1] - mean_setosa[1])**2 + (row[2] - mean_setosa[2])**2 + (row[3] - mean_setosa[3])**2))
    distance['Versicolour'] = (math.sqrt((row[0] - mean_versicolour[0])**2 + (row[1] - mean_versicolour[1])**2 + (row[2] - mean_versicolour[2])**2 + (row[3] - mean_versicolour[3])**2))
    distance['Virginica'] = (math.sqrt((row[0] - mean_virginica[0])**2 + (row[1] - mean_virginica[1])**2 + (row[2] - mean_virginica[2])**2 + (row[3] - mean_virginica[3])**2))
    return list(distance.keys())[list(distance.values()).index(min(distance.values()))]

# %%
distance(data.iloc[0])
# Out:
# 'Setosa'

# %%
distance(data.iloc[0])
# Out:
# 'Setosa'

# %%
for i in range(len(data)):
    print(f'The point{list()}')
# Out:
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]
# The point[]

# %%
data
# Out:
#       x1   x2   x3   x4                 y
# 9    4.9  3.1  1.5  0.1       Iris-Setosa
# 10   5.4  3.7  1.5  0.2       Iris-Setosa
# 13   4.3  3.0  1.1  0.1       Iris-Setosa
# 17   5.1  3.5  1.4  0.3       Iris-Setosa
# 21   5.1  3.7  1.5  0.4       Iris-Setosa
# 30   4.8  3.1  1.6  0.2       Iris-Setosa
# 33   5.5  4.2  1.4  0.2       Iris-Setosa
# 34   4.9  3.1  1.5  0.2       Iris-Setosa
# 36   5.5  3.5  1.3  0.2       Iris-Setosa
# 46   5.1  3.8  1.6  0.2       Iris-Setosa
# 52   6.9  3.1  4.9  1.5  Iris-Versicolour
# 53   5.5  2.3  4.0  1.3  Iris-Versicolour
# 56   6.3  3.3  4.7  1.6  Iris-Versicolour
# 60   5.0  2.0  3.5  1.0  Iris-Versicolour
# 65   6.7  3.1  4.4  1.4  Iris-Versicolour
# 70   5.9  3.2  4.8  1.8  Iris-Versicolour
# 78   6.0  2.9  4.5  1.5  Iris-Versicolour
# 82   5.8  2.7  3.9  1.2  Iris-Versicolour
# 83   6.0  2.7  5.1  1.6  Iris-Versicolour
# 99   5.7  2.8  4.1  1.3  Iris-Versicolour
# 102  7.1  3.0  5.9  2.1    Iris-Virginica
# ...

# %%
data.iloc[0]
# Out:
# x1            4.9
# x2            3.1
# x3            1.5
# x4            0.1
# y     Iris-Setosa
# Name: 9, dtype: object

# %%
test_data = data.copy()

# %%
test_data
# Out:
#       x1   x2   x3   x4                 y
# 9    4.9  3.1  1.5  0.1       Iris-Setosa
# 10   5.4  3.7  1.5  0.2       Iris-Setosa
# 13   4.3  3.0  1.1  0.1       Iris-Setosa
# 17   5.1  3.5  1.4  0.3       Iris-Setosa
# 21   5.1  3.7  1.5  0.4       Iris-Setosa
# 30   4.8  3.1  1.6  0.2       Iris-Setosa
# 33   5.5  4.2  1.4  0.2       Iris-Setosa
# 34   4.9  3.1  1.5  0.2       Iris-Setosa
# 36   5.5  3.5  1.3  0.2       Iris-Setosa
# 46   5.1  3.8  1.6  0.2       Iris-Setosa
# 52   6.9  3.1  4.9  1.5  Iris-Versicolour
# 53   5.5  2.3  4.0  1.3  Iris-Versicolour
# 56   6.3  3.3  4.7  1.6  Iris-Versicolour
# 60   5.0  2.0  3.5  1.0  Iris-Versicolour
# 65   6.7  3.1  4.4  1.4  Iris-Versicolour
# 70   5.9  3.2  4.8  1.8  Iris-Versicolour
# 78   6.0  2.9  4.5  1.5  Iris-Versicolour
# 82   5.8  2.7  3.9  1.2  Iris-Versicolour
# 83   6.0  2.7  5.1  1.6  Iris-Versicolour
# 99   5.7  2.8  4.1  1.3  Iris-Versicolour
# 102  7.1  3.0  5.9  2.1    Iris-Virginica
# ...

# %%
indices_to_select = np.random.choice(test_data.index, size=30, replace=False)
test_points = test_data.loc[indices_to_select]

# %%
test_points
# Out:
#       x1   x2   x3   x4                 y
# 70   5.9  3.2  4.8  1.8  Iris-Versicolour
# 108  6.7  2.5  5.8  1.8    Iris-Virginica
# 56   6.3  3.3  4.7  1.6  Iris-Versicolour
# 130  7.4  2.8  6.1  1.9    Iris-Virginica
# 82   5.8  2.7  3.9  1.2  Iris-Versicolour
# 142  5.8  2.7  5.1  1.9    Iris-Virginica
# 145  6.7  3.0  5.2  2.3    Iris-Virginica
# 17   5.1  3.5  1.4  0.3       Iris-Setosa
# 46   5.1  3.8  1.6  0.2       Iris-Setosa
# 104  6.5  3.0  5.8  2.2    Iris-Virginica
# 36   5.5  3.5  1.3  0.2       Iris-Setosa
# 83   6.0  2.7  5.1  1.6  Iris-Versicolour
# 147  6.5  3.0  5.2  2.0    Iris-Virginica
# 123  6.3  2.7  4.9  1.8    Iris-Virginica
# 30   4.8  3.1  1.6  0.2       Iris-Setosa
# 65   6.7  3.1  4.4  1.4  Iris-Versicolour
# 103  6.3  2.9  5.6  1.8    Iris-Virginica
# 33   5.5  4.2  1.4  0.2       Iris-Setosa
# 120  6.9  3.2  5.7  2.3    Iris-Virginica
# 13   4.3  3.0  1.1  0.1       Iris-Setosa
# 53   5.5  2.3  4.0  1.3  Iris-Versicolour
# ...

# %%
indices_to_select
# Out:
# array([ 70, 108,  56, 130,  82, 142, 145,  17,  46, 104,  36,  83, 147,
#        123,  30,  65, 103,  33, 120,  13,  53, 102,  21,  78,   9,  99,
#         52,  10,  60,  34], dtype=int64)

# %%
test_points.iloc[13]
test_points.index
# Out:
# Index([ 70, 108,  56, 130,  82, 142, 145,  17,  46, 104,  36,  83, 147, 123,
#         30,  65, 103,  33, 120,  13,  53, 102,  21,  78,   9,  99,  52,  10,
#         60,  34],
#       dtype='int64')

# %%
test_points
# Out:
#       x1   x2   x3   x4                 y
# 70   5.9  3.2  4.8  1.8  Iris-Versicolour
# 108  6.7  2.5  5.8  1.8    Iris-Virginica
# 56   6.3  3.3  4.7  1.6  Iris-Versicolour
# 130  7.4  2.8  6.1  1.9    Iris-Virginica
# 82   5.8  2.7  3.9  1.2  Iris-Versicolour
# 142  5.8  2.7  5.1  1.9    Iris-Virginica
# 145  6.7  3.0  5.2  2.3    Iris-Virginica
# 17   5.1  3.5  1.4  0.3       Iris-Setosa
# 46   5.1  3.8  1.6  0.2       Iris-Setosa
# 104  6.5  3.0  5.8  2.2    Iris-Virginica
# 36   5.5  3.5  1.3  0.2       Iris-Setosa
# 83   6.0  2.7  5.1  1.6  Iris-Versicolour
# 147  6.5  3.0  5.2  2.0    Iris-Virginica
# 123  6.3  2.7  4.9  1.8    Iris-Virginica
# 30   4.8  3.1  1.6  0.2       Iris-Setosa
# 65   6.7  3.1  4.4  1.4  Iris-Versicolour
# 103  6.3  2.9  5.6  1.8    Iris-Virginica
# 33   5.5  4.2  1.4  0.2       Iris-Setosa
# 120  6.9  3.2  5.7  2.3    Iris-Virginica
# 13   4.3  3.0  1.1  0.1       Iris-Setosa
# 53   5.5  2.3  4.0  1.3  Iris-Versicolour
# ...

# %%
def actual()

# %%
actual_values = []
predicted_values = []
for i in range(len(test_points)):
    predicted_values.append('Iris-'+distance(test_points.iloc[i]))
    actual_values.append(list(test_points.iloc[i])[-1])
    print(f'The point {list(test_points.iloc[i, :4])} lies in the {distance(test_points.iloc[i, :4])} cluster')
# Out:
# The point [5.9, 3.2, 4.8, 1.8] lies in the Versicolour cluster
# The point [6.7, 2.5, 5.8, 1.8] lies in the Virginica cluster
# The point [6.3, 3.3, 4.7, 1.6] lies in the Versicolour cluster
# The point [7.4, 2.8, 6.1, 1.9] lies in the Virginica cluster
# The point [5.8, 2.7, 3.9, 1.2] lies in the Versicolour cluster
# The point [5.8, 2.7, 5.1, 1.9] lies in the Virginica cluster
# The point [6.7, 3.0, 5.2, 2.3] lies in the Virginica cluster
# The point [5.1, 3.5, 1.4, 0.3] lies in the Setosa cluster
# The point [5.1, 3.8, 1.6, 0.2] lies in the Setosa cluster
# The point [6.5, 3.0, 5.8, 2.2] lies in the Virginica cluster
# The point [5.5, 3.5, 1.3, 0.2] lies in the Setosa cluster
# The point [6.0, 2.7, 5.1, 1.6] lies in the Virginica cluster
# The point [6.5, 3.0, 5.2, 2.0] lies in the Virginica cluster
# The point [6.3, 2.7, 4.9, 1.8] lies in the Virginica cluster
# The point [4.8, 3.1, 1.6, 0.2] lies in the Setosa cluster
# ...

# %%
distance(test_points.iloc[1])
# Out:
# 'Virginica'

# %%
actual_values
# Out:
# ['Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Setosa',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Versicolour',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Setosa']

# %%
predicted_values
# Out:
# ['Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Setosa',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Virginica',
#  'Iris-Virginica',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Virginica',
#  'Iris-Setosa',
#  'Iris-Versicolour',
#  'Iris-Setosa']

# %%
count = 0
for i in range(len(actual_values)):
    if actual_values[i] == predicted_values[i]:
        count += 1
count/len(actual_values)*100
# Out:
# 93.33333333333333

# %%
count
# Out:
# 28

# %%
(sum(np.array(actual_values)==np.array(predicted_values))/30)*100
# Out:
# 93.33333333333333
