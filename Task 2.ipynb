# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
file = pd.read_csv('Iris-Dataset.csv')
data = file.copy()
file
# Out:
#       x1   x2   x3   x4               y
# 0    5.1  3.5  1.4  0.2     Iris-Setosa
# 1    4.9  3.0  1.4  0.2     Iris-Setosa
# 2    4.7  3.2  1.3  0.2     Iris-Setosa
# 3    4.6  3.1  1.5  0.2     Iris-Setosa
# 4    5.0  3.6  1.4  0.2     Iris-Setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-Virginica
# 146  6.3  2.5  5.0  1.9  Iris-Virginica
# 147  6.5  3.0  5.2  2.0  Iris-Virginica
# 148  6.2  3.4  5.4  2.3  Iris-Virginica
# 149  5.9  3.0  5.1  1.8  Iris-Virginica
#
# [150 rows x 5 columns]

# %%
cluster_setosa = data[data['y'] == 'Iris-Setosa']
cluster_versicolour = data[data['y'] == 'Iris-Versicolour']
cluster_virginica = data[data['y'] == 'Iris-Virginica']
cluster_setosa
# Out:
#      x1   x2   x3   x4            y
# 0   5.1  3.5  1.4  0.2  Iris-Setosa
# 1   4.9  3.0  1.4  0.2  Iris-Setosa
# 2   4.7  3.2  1.3  0.2  Iris-Setosa
# 3   4.6  3.1  1.5  0.2  Iris-Setosa
# 4   5.0  3.6  1.4  0.2  Iris-Setosa
# 5   5.4  3.9  1.7  0.4  Iris-Setosa
# 6   4.6  3.4  1.4  0.3  Iris-Setosa
# 7   5.0  3.4  1.5  0.2  Iris-Setosa
# 8   4.4  2.9  1.4  0.2  Iris-Setosa
# 9   4.9  3.1  1.5  0.1  Iris-Setosa
# 10  5.4  3.7  1.5  0.2  Iris-Setosa
# 11  4.8  3.4  1.6  0.2  Iris-Setosa
# 12  4.8  3.0  1.4  0.1  Iris-Setosa
# 13  4.3  3.0  1.1  0.1  Iris-Setosa
# 14  5.8  4.0  1.2  0.2  Iris-Setosa
# 15  5.7  4.4  1.5  0.4  Iris-Setosa
# 16  5.4  3.9  1.3  0.4  Iris-Setosa
# 17  5.1  3.5  1.4  0.3  Iris-Setosa
# 18  5.7  3.8  1.7  0.3  Iris-Setosa
# 19  5.1  3.8  1.5  0.3  Iris-Setosa
# 20  5.4  3.4  1.7  0.2  Iris-Setosa
# 21  5.1  3.7  1.5  0.4  Iris-Setosa
# 22  4.6  3.6  1.0  0.2  Iris-Setosa
# 23  5.1  3.3  1.7  0.5  Iris-Setosa
# 24  4.8  3.4  1.9  0.2  Iris-Setosa
# ...

# %%
cluster_versicolour
# Out:
#      x1   x2   x3   x4                 y
# 50  7.0  3.2  4.7  1.4  Iris-Versicolour
# 51  6.4  3.2  4.5  1.5  Iris-Versicolour
# 52  6.9  3.1  4.9  1.5  Iris-Versicolour
# 53  5.5  2.3  4.0  1.3  Iris-Versicolour
# 54  6.5  2.8  4.6  1.5  Iris-Versicolour
# 55  5.7  2.8  4.5  1.3  Iris-Versicolour
# 56  6.3  3.3  4.7  1.6  Iris-Versicolour
# 57  4.9  2.4  3.3  1.0  Iris-Versicolour
# 58  6.6  2.9  4.6  1.3  Iris-Versicolour
# 59  5.2  2.7  3.9  1.4  Iris-Versicolour
# 60  5.0  2.0  3.5  1.0  Iris-Versicolour
# 61  5.9  3.0  4.2  1.5  Iris-Versicolour
# 62  6.0  2.2  4.0  1.0  Iris-Versicolour
# 63  6.1  2.9  4.7  1.4  Iris-Versicolour
# 64  5.6  2.9  3.6  1.3  Iris-Versicolour
# 65  6.7  3.1  4.4  1.4  Iris-Versicolour
# 66  5.6  3.0  4.5  1.5  Iris-Versicolour
# 67  5.8  2.7  4.1  1.0  Iris-Versicolour
# 68  6.2  2.2  4.5  1.5  Iris-Versicolour
# 69  5.6  2.5  3.9  1.1  Iris-Versicolour
# 70  5.9  3.2  4.8  1.8  Iris-Versicolour
# 71  6.1  2.8  4.0  1.3  Iris-Versicolour
# ...

# %%
cluster_virginica
# Out:
#       x1   x2   x3   x4               y
# 100  6.3  3.3  6.0  2.5  Iris-Virginica
# 101  5.8  2.7  5.1  1.9  Iris-Virginica
# 102  7.1  3.0  5.9  2.1  Iris-Virginica
# 103  6.3  2.9  5.6  1.8  Iris-Virginica
# 104  6.5  3.0  5.8  2.2  Iris-Virginica
# 105  7.6  3.0  6.6  2.1  Iris-Virginica
# 106  4.9  2.5  4.5  1.7  Iris-Virginica
# 107  7.3  2.9  6.3  1.8  Iris-Virginica
# 108  6.7  2.5  5.8  1.8  Iris-Virginica
# 109  7.2  3.6  6.1  2.5  Iris-Virginica
# 110  6.5  3.2  5.1  2.0  Iris-Virginica
# 111  6.4  2.7  5.3  1.9  Iris-Virginica
# 112  6.8  3.0  5.5  2.1  Iris-Virginica
# 113  5.7  2.5  5.0  2.0  Iris-Virginica
# 114  5.8  2.8  5.1  2.4  Iris-Virginica
# 115  6.4  3.2  5.3  2.3  Iris-Virginica
# 116  6.5  3.0  5.5  1.8  Iris-Virginica
# 117  7.7  3.8  6.7  2.2  Iris-Virginica
# 118  7.7  2.6  6.9  2.3  Iris-Virginica
# 119  6.0  2.2  5.0  1.5  Iris-Virginica
# 120  6.9  3.2  5.7  2.3  Iris-Virginica
# 121  5.6  2.8  4.9  2.0  Iris-Virginica
# ...

# %%
plt.scatter(cluster_setosa['x1'], cluster_setosa['x2'])
plt.scatter(cluster_versicolour['x1'], cluster_versicolour['x2'], color='orange')
plt.scatter(cluster_virginica['x1'], cluster_virginica['x2'],color='limegreen')
plt.show()

# %%
mean_setosa = [sum(cluster_setosa.iloc[:, i])/len(cluster_setosa) for i in range(4)]

# %%
mean_setosa
# Out:
# [5.005999999999999, 3.428000000000001, 1.4620000000000002, 0.2459999999999999]

# %%
sum(data.iloc[:, 0])
# Out:
# 876.5000000000002

# %%
mean_versicolour = [sum(cluster_versicolour.iloc[:, i])/len(cluster_versicolour) for i in range(4)]
mean_versicolour
# Out:
# [5.936, 2.7700000000000005, 4.26, 1.3259999999999998]

# %%
mean_virginica = [sum(cluster_virginica.iloc[:, i])/len(cluster_virginica) for i in range(4)]
mean_virginica
# Out:
# [6.587999999999998, 2.9739999999999998, 5.552, 2.026]

# %%
random_point = [7.3, 2.5, 5.7, 3.9]
random_point
# Out:
# [7.3, 2.5, 5.7, 3.9]

# %%
distance = {}
distance['Setosa'] = (math.sqrt((random_point[0] - mean_setosa[0])**2 + (random_point[1] - mean_setosa[1])**2 + (random_point[2] - mean_setosa[2])**2 + (random_point[3] - mean_setosa[3])**2))
distance['Versicolour'] = (math.sqrt((random_point[0] - mean_versicolour[0])**2 + (random_point[1] - mean_versicolour[1])**2 + (random_point[2] - mean_versicolour[2])**2 + (random_point[3] - mean_versicolour[3])**2))
distance['Virginica'] = (math.sqrt((random_point[0] - mean_virginica[0])**2 + (random_point[1] - mean_virginica[1])**2 + (random_point[2] - mean_virginica[2])**2 + (random_point[3] - mean_virginica[3])**2))

# %%
distance
# Out:
# {'Setosa': 6.11849491296675,
#  'Versicolour': 3.2607471536443913,
#  'Virginica': 2.0652844840360376}

# %%
min(distance.values())
# Out:
# 2.0652844840360376

# %%
min_distance = list(distance.keys())[list(distance.values()).index(min(distance.values()))]

# %%
print(f'The point lies in the {min_distance} cluster')
# Out:
# The point lies in the Virginica cluster
